# %% [markdown]
# # Describing Distributions
# Student Name: Nathalie Castro

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats

# %%
# Remote URL to data
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vR_e8C18AejPhQs1YeE9YWo8HtsUymYT3nBiqTi7-2M0LUncBStzTWD3PdDyYgZFcZ5q5T1NRM77NHV/pub?output=csv"
# Load the data
df = pd.read_csv(url)
# Verify it loaded
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
# Get the target column's mean
mean_1 = df["VitD_levels"].mean()
# Get the target column's median
median_1 = df["VitD_levels"].median()
# Get the target column's +1 STD
std_plus_one_1 = mean_1 + df["VitD_levels"].std()
# Get the target column's -1 STD
std_minus_one_1 = mean_1 - df["VitD_levels"].std()

# %%
# Define figure and axes
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=df, x="VitD_levels", stat="probability", kde=True)
# Set the title
ax.set_title("Vitamin D Levels")
# Draw the mean line
ax.axvline(mean_1, 
           color="red",
           label=f"Mean = {round(mean_1, 2)}",
           linewidth=4)
# Draw the median line
ax.axvline(median_1, 
           color="green",
           label=f"Median = {round(median_1, 2)}",
           linewidth=2,
           ls="--")
# Draw the -1 STD line
ax.axvline(std_minus_one_1, 
           color="black",
           label=f"-1 STD = {round(std_minus_one_1, 2)}",
           linewidth=3)
# Draw the +1 STD lin
ax.axvline(std_plus_one_1, 
           color="black",
           label=f"+1 STD = {round(std_plus_one_1, 2)}",
           linewidth=3)
# Highlight the range between -1 STD and +1 STD
ax.axvspan(std_minus_one_1, std_plus_one_1, color="yellow", zorder=0)
# Supply a legend
ax.legend();

# %%
# Calculate kurtosis
kurtosis = stats.kurtosis(df["VitD_levels"] , fisher=False)
kurtosis
# Out:
# 3.013147515833447

# %% [markdown]
# 1. Is it Discrete or Continuous?
# > * This is a continuous distribution.
# 2. Does it have a skew? If so, which direction (+/-)
# > * This does not have a significant skew.
# 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
# > * The distribution above displays Mesokurtic Kurtosis.

# %%
# Get the target column's mean
mean_2 = df["Doc_visits"].mean()
# Get the target column's median
median_2 = df["Doc_visits"].median()
# Get the target column's +1 STD
std_plus_one_2 = mean_2 + df["Doc_visits"].std()
# Get the target column's -1 STD
std_minus_one_2 = mean_2 - df["Doc_visits"].std()

# %%
# Define figure and axes
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=df, x="Doc_visits", stat="probability", kde=True)
# Set the title
ax.set_title("Doctor Visit Count")
# Draw the mean line
ax.axvline(mean_2, 
           color="red",
           label=f"Mean = {round(mean_2, 2)}",
           linewidth=4)
# Draw the median line
ax.axvline(median_2, 
           color="green",
           label=f"Median = {round(median_2, 2)}",
           linewidth=2,
           ls="--")
# Draw the -1 STD line
ax.axvline(std_minus_one_2, 
           color="black",
           label=f"-1 STD = {round(std_minus_one_2, 2)}",
           linewidth=3)
# Draw the +1 STD lin
ax.axvline(std_plus_one_2, 
           color="black",
           label=f"+1 STD = {round(std_plus_one_2, 2)}",
           linewidth=3)
# Highlight the range between -1 STD and +1 STD
ax.axvspan(std_minus_one_2, std_plus_one_2, color="yellow", zorder=0)
# Supply a legend
ax.legend();

# %%
# Calculate kurtosis
kurtosis_2 = stats.kurtosis(df["Doc_visits"] , fisher=False)
kurtosis_2
# Out:
# 2.9919958083381206

# %% [markdown]
# 1. Is it Discrete or Continuous?
# > * This is a discrete distribution.
# 2. Does it have a skew? If so, which direction (+/-)
# > * This does not have a significant skew.
# 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
# > * The distribution above displays Mesokurtic Kurtosis.

# %%
# Get the target column's mean
mean_3 = df["TotalCharge"].mean()
# Get the target column's median
median_3 = df["TotalCharge"].median()
# Get the target column's +1 STD
std_plus_one_3 = mean_3 + df["TotalCharge"].std()
# Get the target column's -1 STD
std_minus_one_3 = mean_3 - df["TotalCharge"].std()

# %%
# Define figure and axes
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=df, x="TotalCharge", stat="probability", kde=True)
# Set the title
ax.set_title("Total Charges")
# Draw the mean line
ax.axvline(mean_3, 
           color="red",
           label=f"Mean = {round(mean_3, 2)}",
           linewidth=4)
# Draw the median line
ax.axvline(median_3, 
           color="green",
           label=f"Median = {round(median_3, 2)}",
           linewidth=2,
           ls="--")
# Draw the -1 STD line
ax.axvline(std_minus_one_3, 
           color="black",
           label=f"-1 STD = {round(std_minus_one_3, 2)}",
           linewidth=3)
# Draw the +1 STD lin
ax.axvline(std_plus_one_3, 
           color="black",
           label=f"+1 STD = {round(std_plus_one_3, 2)}",
           linewidth=3)
# Highlight the range between -1 STD and +1 STD
ax.axvspan(std_minus_one_3, std_plus_one_3, color="yellow", zorder=0)
# Supply a legend
ax.legend();

# %%
# Calculate kurtosis
kurtosis_3 = stats.kurtosis(df["TotalCharge"] , fisher=False)
kurtosis_3
# Out:
# 3.2650077463439384

# %% [markdown]
# 1. Is it Discrete or Continuous?
# > * This is a continious distribution.
# 2. Does it have a skew? If so, which direction (+/-)
# > * This is  positively skewed.
# 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
# > * The distribution above displays Leptokurtic Kurtosis.
